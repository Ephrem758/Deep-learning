# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from collections import OrderedDict
from torch.utils.data import Dataset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import copy
import time

import datetime
from torch.utils.tensorboard import SummaryWriter
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve, auc
from torch.optim.lr_scheduler import CosineAnnealingLR,ReduceLROnPlateau

# %%
# !pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.10/dist-packages (0.2.1)

# %%
from sklearn.metrics import f1_score,precision_score,recall_score,accuracy_score

# Function to get the learning rate
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

# Function to compute the loss value per batch of data
def loss_batch(loss_func, output, target, opt=None):

    loss = loss_func(output, target) # get loss

    if(opt is not None):
        opt.zero_grad()
        loss.backward()
        opt.step()

    return loss

def accuracy(y_pred, y_test):
    y_pred_tag = torch.round(torch.sigmoid(y_pred))
    acc = accuracy_score(y_test,y_pred_tag.detach().numpy())
    acc = round(100*acc)
    return acc

def recall(y_pred, y_test):
    y_pred_tag = torch.round(torch.sigmoid(y_pred))
    get_recall = recall_score(y_test,y_pred_tag.detach().numpy())
    get_recall = round(100*get_recall)
    return get_recall

def precision(y_pred, y_test):
    y_pred_tag = torch.round(torch.sigmoid(y_pred))
    get_precision = precision_score(y_test,y_pred_tag.detach().numpy())
    get_precision = round(100*get_precision)
    return get_precision

def f1(y_pred, y_test):
    y_pred_tag = torch.round(torch.sigmoid(y_pred))
    get_f1 = f1_score(y_test,y_pred_tag.detach().numpy())
    get_f1 = round(100*get_f1)
    return get_f1

# Compute the loss value & performance metric for the entire dataset (epoch)
def loss_epoch(model,loss_func,dataset_dl,eval_funcs,opt=None):

    run_loss=0.0

    t_metric = {}; metric = {}
    for i in eval_funcs:
        t_metric[i] = 0.0

    # internal loop over dataset
    for xb, yb in dataset_dl:
        xb=xb.to(device)
        yb=yb.to(device)
        y_pred  = model(xb)

        loss = loss_batch(loss_func,y_pred, yb.unsqueeze(1),opt=opt)

        for feval in eval_funcs:
            if(feval == 'accuracy'):
                t_metric[feval] += accuracy(y_pred, yb.unsqueeze(1))
            if(feval == 'f1'):
                t_metric[feval] += f1(y_pred,yb.unsqueeze(1))
            if(feval == 'recall'):
                t_metric[feval] += recall(y_pred,yb.unsqueeze(1))

        run_loss += loss.item()
    loss=run_loss/len(dataset_dl)  # average loss value

    for feval in eval_funcs:
        temp = t_metric[feval]/len(dataset_dl)
        metric[feval] = temp  # average metric value


    return loss, metric

# Training Function
def train_val(model, params,verbose=False):

    t0 = time.time()

    epochs=params["epochs"]
    loss_func=params["f_loss"]
    opt=params["optimiser"]
    train_dl=params["train"]
    val_dl=params["val"]
    lr_scheduler=params["lr_change"]
    weight_path=params["weight_path"]
    eval_funcs = params['eval_func'] # list of evaluation functions
    write_metric = params['write_metric']

    loss_history={"train": [],"val": []} # history of loss values in each epoch
    best_model_wts = copy.deepcopy(model.state_dict()) # a deep copy of weights for the best performing model
    best_loss=float('inf') # initialize best loss to a large value

    tr_dict_eval = {}; te_dict_eval = {}
    for evals in eval_funcs:
        tr_dict_eval[evals] = []
        te_dict_eval[evals] = []

    for epoch in range(epochs):

        current_lr=get_lr(opt)
        model.train()
        train_loss, train_metric = loss_epoch(model,loss_func,train_dl,eval_funcs,opt)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model,loss_func,val_dl,eval_funcs)

        if(val_loss < best_loss):
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), weight_path)

        loss_history["train"].append(train_loss)
        loss_history["val"].append(val_loss)

        for evals in eval_funcs:
            tr_dict_eval[evals].append(train_metric[evals])
            te_dict_eval[evals].append(val_metric[evals])

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            if(verbose):
                print("Saving best model weights!")
            model.load_state_dict(best_model_wts)

        if(verbose):
            print(f"epoch: {epoch+1+0:03} | train loss: {train_loss:.3f} | val loss: {val_loss:.3f} | train-{write_metric}: {train_metric[write_metric]:.3f} val-{write_metric}: {val_metric[write_metric]:.3f}")

    # load best model weights
    model.load_state_dict(best_model_wts)

    t1 = time.time()
    print(f'Total Time: {t1-t0:.3f}')

    return model, loss_history, {'train':tr_dict_eval,'val':te_dict_eval}

# %%
import pandas as pd

df = pd.read_csv('Dataset_spine.csv')
df.drop([df.columns[-1]],axis=1,inplace=True)

df['Class_att'] = df['Class_att'].astype('category')
encode_map = {
    'Abnormal': 1,
    'Normal': 0
}

df['Class_att'].replace(encode_map, inplace=True)
df['Class_att'].value_counts()
# Out:
# 1    210
# 0    100
# Name: Class_att, dtype: int64

# %%
df.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6  \
# 0  63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
#
#        Col7     Col8     Col9     Col10      Col11    Col12 Class_att
# 0  0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123         1
# 1  0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102         1
# 2  0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221         1
# 3  0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329         1
# 4  0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171         1

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

y = df['Class_att']
X = df.drop(['Class_att'],axis=1)

X_train, X_val, y_train, y_val = train_test_split(X, y,
                                                  test_size=0.20,
                                                  random_state=13,
                                                  shuffle=True)
print(f'X_train: {X_train.shape}')
print(f'X_val: {X_val.shape}')
# Out:
# X_train: (248, 12)
# X_val: (62, 12)

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=2,subplot_titles=['Train','Validation'])
itrace = px.scatter(x=X_train['Col1'],
                    y=X_train['Col2'],
                    color=y_train,
                   )['data'][0]
trace = px.scatter(x=X_val['Col1'],
                   y=X_val['Col2'],
                   color=y_val,
                  )['data'][0]

fig.add_trace(itrace, row=1, col=1)
fig.add_trace(trace, row=1, col=2)

fig.update_layout(template='plotly_white',
                  title='Train / Validation Data Splitting',
                  font=dict(family='sans-serif',size=12),
                  width=1200)

fig.update_traces({'marker_line_width':1.5,
                   'marker_line_color':"black",
                   'marker_size':7,
                   'opacity':1.0,
                  })

fig.update_layout(showlegend=True)
fig.update_coloraxes(colorscale="tealgrn")
fig.update_layout(coloraxis_showscale=False)
fig.update_layout(showlegend=True)
fig.show(renderer="svg")

# %%
X_train = X_train.values
X_val = X_val.values
y_train = y_train.values
y_val = y_val.values

sc = StandardScaler()
sc.fit(X_train)

X_train = sc.transform(X_train)
X_val = sc.transform(X_val)

# %%
X_train_tensor = torch.FloatTensor(X_train)
X_val_tensor = torch.FloatTensor(X_val)
y_train_tensor = torch.FloatTensor(y_train)
y_val_tensor = torch.FloatTensor(y_val)

# Builds dataset containing ALL data points
train_dataset = TensorDataset(X_train_tensor,
                              y_train_tensor)
val_dataset = TensorDataset(X_val_tensor,
                            y_val_tensor)

# Builds a loader of each set
batch_size = 16
train_loader = DataLoader(dataset=train_dataset,
                          batch_size=batch_size,
                          shuffle=True)

val_loader = DataLoader(dataset=val_dataset,
                        batch_size=batch_size)

# %%
for x,y in train_loader:
    print(x.shape,y)
    break
# Out:
# torch.Size([16, 12]) tensor([1., 0., 1., 1., 1., 1., 1., 1., 1., 0., 1., 1., 1., 1., 1., 0.])

# %%
class BinaryClassification(nn.Module):

    def __init__(self):
        super(BinaryClassification, self).__init__()
        # Number of input features is 12.
        self.layer_1 = nn.Linear(12, 64)
        self.layer_2 = nn.Linear(64, 64)
        self.layer_out = nn.Linear(64, 1)

        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.1)
        self.batchnorm1 = nn.BatchNorm1d(64)
        self.batchnorm2 = nn.BatchNorm1d(64)

    def forward(self, inputs):
        x = self.relu(self.layer_1(inputs))
        x = self.batchnorm1(x)
        x = self.relu(self.layer_2(x))
        x = self.batchnorm2(x)
        x = self.dropout(x)
        x = self.layer_out(x)

        return x

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = BinaryClassification()
opt = optim.Adam(model.parameters(), lr=1e-4)
loss = nn.BCEWithLogitsLoss()

# Create Parameter Dictionary
params_train={
  "train": train_loader,
    "val": val_loader,
 "epochs": 200,
 "optimiser": opt,
 "lr_change": ReduceLROnPlateau(opt,
                                mode='min',
                                factor=0.5,
                                patience=20,verbose=0),
 "f_loss": loss,
 "weight_path": "weights.pt",
 "eval_func" : ['accuracy','f1','recall','precision'],
 "write_metric" : 'f1'
}

nn_model,loss_hist,metric_hist=train_val(model,params_train,verbose=True)
epochs=params_train["epochs"]
# Out:
# epoch: 001 | train loss: 0.728 | val loss: 0.706 | train-f1: 57.688 val-f1: 48.250
# epoch: 002 | train loss: 0.703 | val loss: 0.696 | train-f1: 60.125 val-f1: 59.250
# epoch: 003 | train loss: 0.682 | val loss: 0.685 | train-f1: 62.125 val-f1: 62.000
# epoch: 004 | train loss: 0.657 | val loss: 0.660 | train-f1: 68.688 val-f1: 66.250
# epoch: 005 | train loss: 0.639 | val loss: 0.630 | train-f1: 73.125 val-f1: 67.500
# epoch: 006 | train loss: 0.615 | val loss: 0.626 | train-f1: 72.188 val-f1: 67.500
# epoch: 007 | train loss: 0.618 | val loss: 0.607 | train-f1: 73.438 val-f1: 70.000
# epoch: 008 | train loss: 0.608 | val loss: 0.593 | train-f1: 73.125 val-f1: 72.500
# epoch: 009 | train loss: 0.596 | val loss: 0.569 | train-f1: 74.562 val-f1: 74.500
# epoch: 010 | train loss: 0.582 | val loss: 0.572 | train-f1: 74.062 val-f1: 72.000
# epoch: 011 | train loss: 0.585 | val loss: 0.560 | train-f1: 75.938 val-f1: 74.500
# epoch: 012 | train loss: 0.565 | val loss: 0.547 | train-f1: 75.000 val-f1: 73.000
# epoch: 013 | train loss: 0.566 | val loss: 0.548 | train-f1: 77.562 val-f1: 74.000
# epoch: 014 | train loss: 0.553 | val loss: 0.538 | train-f1: 76.875 val-f1: 74.000
# epoch: 015 | train loss: 0.541 | val loss: 0.535 | train-f1: 80.562 val-f1: 72.500
# epoch: 016 | train loss: 0.528 | val loss: 0.523 | train-f1: 80.750 val-f1: 74.000
# epoch: 017 | train loss: 0.513 | val loss: 0.517 | train-f1: 80.750 val-f1: 74.000
# epoch: 018 | train loss: 0.515 | val loss: 0.510 | train-f1: 81.375 val-f1: 75.500
# epoch: 019 | train loss: 0.509 | val loss: 0.503 | train-f1: 81.750 val-f1: 74.000
# epoch: 020 | train loss: 0.514 | val loss: 0.494 | train-f1: 78.750 val-f1: 74.000
# epoch: 021 | train loss: 0.501 | val loss: 0.489 | train-f1: 82.688 val-f1: 74.000
# epoch: 022 | train loss: 0.495 | val loss: 0.494 | train-f1: 82.375 val-f1: 74.000
# epoch: 023 | train loss: 0.492 | val loss: 0.487 | train-f1: 82.562 val-f1: 74.000
# epoch: 024 | train loss: 0.502 | val loss: 0.477 | train-f1: 79.750 val-f1: 77.250
# epoch: 025 | train loss: 0.489 | val loss: 0.477 | train-f1: 81.812 val-f1: 75.750
# epoch: 026 | train loss: 0.486 | val loss: 0.476 | train-f1: 82.812 val-f1: 75.750
# epoch: 027 | train loss: 0.480 | val loss: 0.466 | train-f1: 82.062 val-f1: 78.000
# epoch: 028 | train loss: 0.466 | val loss: 0.466 | train-f1: 82.438 val-f1: 75.750
# epoch: 029 | train loss: 0.480 | val loss: 0.471 | train-f1: 81.500 val-f1: 75.750
# epoch: 030 | train loss: 0.468 | val loss: 0.455 | train-f1: 83.438 val-f1: 81.500
# epoch: 031 | train loss: 0.448 | val loss: 0.449 | train-f1: 84.375 val-f1: 83.000
# epoch: 032 | train loss: 0.454 | val loss: 0.450 | train-f1: 82.438 val-f1: 81.500
# epoch: 033 | train loss: 0.452 | val loss: 0.451 | train-f1: 83.938 val-f1: 79.500
# epoch: 034 | train loss: 0.453 | val loss: 0.452 | train-f1: 85.688 val-f1: 79.500
# epoch: 035 | train loss: 0.433 | val loss: 0.447 | train-f1: 87.250 val-f1: 81.500
# epoch: 036 | train loss: 0.452 | val loss: 0.435 | train-f1: 85.375 val-f1: 82.000
# epoch: 037 | train loss: 0.431 | val loss: 0.424 | train-f1: 86.750 val-f1: 82.000
# epoch: 038 | train loss: 0.438 | val loss: 0.428 | train-f1: 83.188 val-f1: 84.500
# epoch: 039 | train loss: 0.428 | val loss: 0.434 | train-f1: 84.688 val-f1: 83.000
# epoch: 040 | train loss: 0.426 | val loss: 0.442 | train-f1: 86.312 val-f1: 79.500
# epoch: 041 | train loss: 0.431 | val loss: 0.420 | train-f1: 85.250 val-f1: 88.000
# epoch: 042 | train loss: 0.401 | val loss: 0.432 | train-f1: 87.875 val-f1: 85.000
# epoch: 043 | train loss: 0.396 | val loss: 0.420 | train-f1: 88.750 val-f1: 85.000
# epoch: 044 | train loss: 0.408 | val loss: 0.418 | train-f1: 88.312 val-f1: 84.500
# epoch: 045 | train loss: 0.410 | val loss: 0.408 | train-f1: 87.750 val-f1: 88.000
# epoch: 046 | train loss: 0.415 | val loss: 0.417 | train-f1: 85.875 val-f1: 86.500
# epoch: 047 | train loss: 0.403 | val loss: 0.411 | train-f1: 85.375 val-f1: 86.500
# epoch: 048 | train loss: 0.392 | val loss: 0.404 | train-f1: 86.188 val-f1: 86.500
# epoch: 049 | train loss: 0.392 | val loss: 0.390 | train-f1: 86.562 val-f1: 88.000
# epoch: 050 | train loss: 0.397 | val loss: 0.424 | train-f1: 87.375 val-f1: 84.500
# epoch: 051 | train loss: 0.365 | val loss: 0.401 | train-f1: 90.312 val-f1: 88.000
# epoch: 052 | train loss: 0.372 | val loss: 0.402 | train-f1: 89.438 val-f1: 86.500
# epoch: 053 | train loss: 0.382 | val loss: 0.403 | train-f1: 88.312 val-f1: 88.000
# epoch: 054 | train loss: 0.356 | val loss: 0.397 | train-f1: 87.812 val-f1: 88.000
# epoch: 055 | train loss: 0.387 | val loss: 0.401 | train-f1: 88.062 val-f1: 88.000
# epoch: 056 | train loss: 0.364 | val loss: 0.397 | train-f1: 90.438 val-f1: 88.000
# epoch: 057 | train loss: 0.363 | val loss: 0.383 | train-f1: 90.500 val-f1: 88.000
# epoch: 058 | train loss: 0.373 | val loss: 0.386 | train-f1: 88.312 val-f1: 88.000
# epoch: 059 | train loss: 0.345 | val loss: 0.373 | train-f1: 90.312 val-f1: 88.000
# epoch: 060 | train loss: 0.345 | val loss: 0.375 | train-f1: 88.688 val-f1: 88.000
# epoch: 061 | train loss: 0.354 | val loss: 0.389 | train-f1: 90.438 val-f1: 88.000
# epoch: 062 | train loss: 0.345 | val loss: 0.367 | train-f1: 90.188 val-f1: 88.000
# epoch: 063 | train loss: 0.356 | val loss: 0.370 | train-f1: 88.062 val-f1: 89.250
# epoch: 064 | train loss: 0.337 | val loss: 0.359 | train-f1: 90.312 val-f1: 89.250
# epoch: 065 | train loss: 0.320 | val loss: 0.363 | train-f1: 90.312 val-f1: 89.250
# epoch: 066 | train loss: 0.326 | val loss: 0.374 | train-f1: 90.750 val-f1: 86.500
# epoch: 067 | train loss: 0.317 | val loss: 0.369 | train-f1: 92.188 val-f1: 86.500
# epoch: 068 | train loss: 0.337 | val loss: 0.365 | train-f1: 90.750 val-f1: 89.250
# epoch: 069 | train loss: 0.336 | val loss: 0.359 | train-f1: 89.562 val-f1: 89.250
# epoch: 070 | train loss: 0.315 | val loss: 0.360 | train-f1: 92.312 val-f1: 89.250
# epoch: 071 | train loss: 0.317 | val loss: 0.363 | train-f1: 91.000 val-f1: 89.250
# epoch: 072 | train loss: 0.325 | val loss: 0.363 | train-f1: 89.562 val-f1: 89.250
# epoch: 073 | train loss: 0.327 | val loss: 0.371 | train-f1: 91.375 val-f1: 87.750
# epoch: 074 | train loss: 0.291 | val loss: 0.356 | train-f1: 92.375 val-f1: 89.250
# epoch: 075 | train loss: 0.310 | val loss: 0.363 | train-f1: 90.750 val-f1: 87.750
# epoch: 076 | train loss: 0.299 | val loss: 0.357 | train-f1: 92.062 val-f1: 87.750
# epoch: 077 | train loss: 0.315 | val loss: 0.361 | train-f1: 90.375 val-f1: 89.250
# epoch: 078 | train loss: 0.314 | val loss: 0.360 | train-f1: 91.000 val-f1: 89.250
# epoch: 079 | train loss: 0.300 | val loss: 0.350 | train-f1: 92.062 val-f1: 89.250
# epoch: 080 | train loss: 0.280 | val loss: 0.359 | train-f1: 92.250 val-f1: 87.750
# epoch: 081 | train loss: 0.277 | val loss: 0.359 | train-f1: 91.938 val-f1: 87.750
# epoch: 082 | train loss: 0.298 | val loss: 0.358 | train-f1: 92.688 val-f1: 87.750
# epoch: 083 | train loss: 0.284 | val loss: 0.351 | train-f1: 93.188 val-f1: 89.250
# epoch: 084 | train loss: 0.307 | val loss: 0.352 | train-f1: 91.500 val-f1: 87.750
# epoch: 085 | train loss: 0.279 | val loss: 0.350 | train-f1: 93.500 val-f1: 89.250
# epoch: 086 | train loss: 0.299 | val loss: 0.355 | train-f1: 92.688 val-f1: 89.250
# epoch: 087 | train loss: 0.272 | val loss: 0.348 | train-f1: 93.312 val-f1: 89.250
# epoch: 088 | train loss: 0.310 | val loss: 0.338 | train-f1: 91.625 val-f1: 89.250
# epoch: 089 | train loss: 0.288 | val loss: 0.343 | train-f1: 92.188 val-f1: 89.250
# epoch: 090 | train loss: 0.289 | val loss: 0.343 | train-f1: 90.312 val-f1: 89.250
# epoch: 091 | train loss: 0.271 | val loss: 0.340 | train-f1: 91.250 val-f1: 88.250
# epoch: 092 | train loss: 0.265 | val loss: 0.342 | train-f1: 93.750 val-f1: 88.250
# epoch: 093 | train loss: 0.306 | val loss: 0.349 | train-f1: 92.000 val-f1: 89.250
# epoch: 094 | train loss: 0.255 | val loss: 0.335 | train-f1: 93.812 val-f1: 89.500
# epoch: 095 | train loss: 0.272 | val loss: 0.330 | train-f1: 91.750 val-f1: 89.500
# epoch: 096 | train loss: 0.270 | val loss: 0.331 | train-f1: 91.188 val-f1: 89.500
# epoch: 097 | train loss: 0.254 | val loss: 0.341 | train-f1: 92.625 val-f1: 88.250
# epoch: 098 | train loss: 0.253 | val loss: 0.334 | train-f1: 94.812 val-f1: 88.250
# epoch: 099 | train loss: 0.272 | val loss: 0.333 | train-f1: 92.438 val-f1: 89.750
# epoch: 100 | train loss: 0.262 | val loss: 0.338 | train-f1: 93.312 val-f1: 89.750
# epoch: 101 | train loss: 0.254 | val loss: 0.328 | train-f1: 94.375 val-f1: 88.250
# epoch: 102 | train loss: 0.269 | val loss: 0.334 | train-f1: 91.750 val-f1: 89.500
# epoch: 103 | train loss: 0.267 | val loss: 0.332 | train-f1: 93.062 val-f1: 90.750
# epoch: 104 | train loss: 0.277 | val loss: 0.337 | train-f1: 91.500 val-f1: 88.250
# epoch: 105 | train loss: 0.260 | val loss: 0.336 | train-f1: 92.375 val-f1: 89.500
# epoch: 106 | train loss: 0.244 | val loss: 0.335 | train-f1: 93.875 val-f1: 88.250
# epoch: 107 | train loss: 0.257 | val loss: 0.333 | train-f1: 92.875 val-f1: 89.500
# epoch: 108 | train loss: 0.296 | val loss: 0.335 | train-f1: 90.625 val-f1: 89.500
# epoch: 109 | train loss: 0.228 | val loss: 0.322 | train-f1: 95.062 val-f1: 91.000
# epoch: 110 | train loss: 0.270 | val loss: 0.326 | train-f1: 92.812 val-f1: 89.500
# epoch: 111 | train loss: 0.232 | val loss: 0.325 | train-f1: 94.438 val-f1: 89.500
# epoch: 112 | train loss: 0.228 | val loss: 0.324 | train-f1: 95.312 val-f1: 89.500
# epoch: 113 | train loss: 0.236 | val loss: 0.329 | train-f1: 94.438 val-f1: 91.000
# epoch: 114 | train loss: 0.245 | val loss: 0.328 | train-f1: 94.000 val-f1: 89.750
# epoch: 115 | train loss: 0.260 | val loss: 0.338 | train-f1: 91.312 val-f1: 89.750
# epoch: 116 | train loss: 0.196 | val loss: 0.325 | train-f1: 96.312 val-f1: 91.000
# epoch: 117 | train loss: 0.219 | val loss: 0.328 | train-f1: 94.438 val-f1: 89.500
# epoch: 118 | train loss: 0.208 | val loss: 0.330 | train-f1: 95.438 val-f1: 91.000
# epoch: 119 | train loss: 0.204 | val loss: 0.325 | train-f1: 94.875 val-f1: 91.000
# epoch: 120 | train loss: 0.221 | val loss: 0.328 | train-f1: 94.500 val-f1: 91.000
# epoch: 121 | train loss: 0.210 | val loss: 0.329 | train-f1: 94.562 val-f1: 91.000
# epoch: 122 | train loss: 0.247 | val loss: 0.329 | train-f1: 91.938 val-f1: 91.000
# epoch: 123 | train loss: 0.204 | val loss: 0.329 | train-f1: 94.938 val-f1: 89.500
# epoch: 124 | train loss: 0.202 | val loss: 0.330 | train-f1: 95.250 val-f1: 91.000
# epoch: 125 | train loss: 0.230 | val loss: 0.317 | train-f1: 93.188 val-f1: 92.250
# epoch: 126 | train loss: 0.214 | val loss: 0.325 | train-f1: 94.875 val-f1: 91.000
# epoch: 127 | train loss: 0.218 | val loss: 0.326 | train-f1: 94.250 val-f1: 91.000
# epoch: 128 | train loss: 0.210 | val loss: 0.337 | train-f1: 93.938 val-f1: 91.000
# epoch: 129 | train loss: 0.212 | val loss: 0.339 | train-f1: 96.938 val-f1: 91.000
# epoch: 130 | train loss: 0.218 | val loss: 0.328 | train-f1: 94.375 val-f1: 91.000
# epoch: 131 | train loss: 0.228 | val loss: 0.330 | train-f1: 92.812 val-f1: 91.000
# epoch: 132 | train loss: 0.189 | val loss: 0.333 | train-f1: 96.125 val-f1: 91.000
# epoch: 133 | train loss: 0.211 | val loss: 0.327 | train-f1: 95.375 val-f1: 91.000
# epoch: 134 | train loss: 0.199 | val loss: 0.321 | train-f1: 95.062 val-f1: 91.000
# epoch: 135 | train loss: 0.185 | val loss: 0.326 | train-f1: 95.250 val-f1: 91.000
# epoch: 136 | train loss: 0.203 | val loss: 0.328 | train-f1: 95.375 val-f1: 89.500
# epoch: 137 | train loss: 0.225 | val loss: 0.326 | train-f1: 93.125 val-f1: 91.000
# epoch: 138 | train loss: 0.227 | val loss: 0.333 | train-f1: 94.562 val-f1: 89.500
# epoch: 139 | train loss: 0.213 | val loss: 0.323 | train-f1: 94.125 val-f1: 91.000
# epoch: 140 | train loss: 0.184 | val loss: 0.333 | train-f1: 94.125 val-f1: 91.000
# epoch: 141 | train loss: 0.155 | val loss: 0.335 | train-f1: 97.188 val-f1: 91.000
# epoch: 142 | train loss: 0.196 | val loss: 0.326 | train-f1: 94.750 val-f1: 91.000
# epoch: 143 | train loss: 0.221 | val loss: 0.332 | train-f1: 93.500 val-f1: 89.750
# epoch: 144 | train loss: 0.235 | val loss: 0.335 | train-f1: 93.312 val-f1: 91.000
# epoch: 145 | train loss: 0.213 | val loss: 0.331 | train-f1: 94.688 val-f1: 91.000
# Saving best model weights!
# epoch: 146 | train loss: 0.196 | val loss: 0.328 | train-f1: 95.250 val-f1: 91.000
# epoch: 147 | train loss: 0.218 | val loss: 0.324 | train-f1: 94.438 val-f1: 91.000
# epoch: 148 | train loss: 0.199 | val loss: 0.321 | train-f1: 96.625 val-f1: 92.250
# epoch: 149 | train loss: 0.203 | val loss: 0.328 | train-f1: 96.500 val-f1: 89.500
# epoch: 150 | train loss: 0.213 | val loss: 0.334 | train-f1: 95.438 val-f1: 88.250
# epoch: 151 | train loss: 0.176 | val loss: 0.331 | train-f1: 96.500 val-f1: 91.000
# epoch: 152 | train loss: 0.190 | val loss: 0.328 | train-f1: 96.062 val-f1: 91.000
# epoch: 153 | train loss: 0.216 | val loss: 0.326 | train-f1: 94.375 val-f1: 91.000
# epoch: 154 | train loss: 0.199 | val loss: 0.330 | train-f1: 95.312 val-f1: 91.000
# epoch: 155 | train loss: 0.252 | val loss: 0.321 | train-f1: 91.750 val-f1: 91.000
# epoch: 156 | train loss: 0.197 | val loss: 0.332 | train-f1: 96.375 val-f1: 89.500
# epoch: 157 | train loss: 0.199 | val loss: 0.323 | train-f1: 96.375 val-f1: 89.500
# epoch: 158 | train loss: 0.213 | val loss: 0.324 | train-f1: 96.000 val-f1: 91.000
# epoch: 159 | train loss: 0.203 | val loss: 0.328 | train-f1: 94.500 val-f1: 89.750
# epoch: 160 | train loss: 0.189 | val loss: 0.323 | train-f1: 95.688 val-f1: 91.000
# epoch: 161 | train loss: 0.187 | val loss: 0.336 | train-f1: 96.312 val-f1: 89.500
# epoch: 162 | train loss: 0.181 | val loss: 0.322 | train-f1: 97.062 val-f1: 91.000
# epoch: 163 | train loss: 0.194 | val loss: 0.331 | train-f1: 94.375 val-f1: 91.000
# epoch: 164 | train loss: 0.179 | val loss: 0.323 | train-f1: 96.312 val-f1: 89.500
# epoch: 165 | train loss: 0.212 | val loss: 0.330 | train-f1: 93.688 val-f1: 91.000
# epoch: 166 | train loss: 0.191 | val loss: 0.321 | train-f1: 95.625 val-f1: 91.000
# Saving best model weights!
# epoch: 167 | train loss: 0.221 | val loss: 0.322 | train-f1: 92.812 val-f1: 92.250
# epoch: 168 | train loss: 0.207 | val loss: 0.329 | train-f1: 95.625 val-f1: 91.000
# epoch: 169 | train loss: 0.190 | val loss: 0.331 | train-f1: 96.312 val-f1: 91.000
# epoch: 170 | train loss: 0.241 | val loss: 0.326 | train-f1: 92.812 val-f1: 92.250
# epoch: 171 | train loss: 0.171 | val loss: 0.329 | train-f1: 98.000 val-f1: 92.250
# epoch: 172 | train loss: 0.245 | val loss: 0.329 | train-f1: 92.875 val-f1: 91.000
# epoch: 173 | train loss: 0.200 | val loss: 0.326 | train-f1: 94.688 val-f1: 91.000
# epoch: 174 | train loss: 0.189 | val loss: 0.332 | train-f1: 96.625 val-f1: 91.000
# epoch: 175 | train loss: 0.205 | val loss: 0.328 | train-f1: 95.312 val-f1: 89.500
# epoch: 176 | train loss: 0.220 | val loss: 0.327 | train-f1: 94.188 val-f1: 91.000
# epoch: 177 | train loss: 0.207 | val loss: 0.333 | train-f1: 95.250 val-f1: 89.500
# epoch: 178 | train loss: 0.192 | val loss: 0.325 | train-f1: 95.562 val-f1: 91.000
# epoch: 179 | train loss: 0.197 | val loss: 0.330 | train-f1: 95.312 val-f1: 89.500
# epoch: 180 | train loss: 0.197 | val loss: 0.325 | train-f1: 94.875 val-f1: 91.000
# epoch: 181 | train loss: 0.205 | val loss: 0.329 | train-f1: 95.438 val-f1: 89.500
# epoch: 182 | train loss: 0.210 | val loss: 0.326 | train-f1: 95.875 val-f1: 89.500
# epoch: 183 | train loss: 0.207 | val loss: 0.333 | train-f1: 94.625 val-f1: 86.750
# epoch: 184 | train loss: 0.188 | val loss: 0.335 | train-f1: 96.062 val-f1: 89.750
# epoch: 185 | train loss: 0.194 | val loss: 0.326 | train-f1: 96.375 val-f1: 91.000
# epoch: 186 | train loss: 0.167 | val loss: 0.323 | train-f1: 97.562 val-f1: 91.000
# epoch: 187 | train loss: 0.206 | val loss: 0.327 | train-f1: 94.688 val-f1: 89.500
# Saving best model weights!
# epoch: 188 | train loss: 0.214 | val loss: 0.326 | train-f1: 93.688 val-f1: 91.000
# epoch: 189 | train loss: 0.215 | val loss: 0.324 | train-f1: 94.812 val-f1: 91.000
# epoch: 190 | train loss: 0.234 | val loss: 0.329 | train-f1: 94.438 val-f1: 91.000
# epoch: 191 | train loss: 0.212 | val loss: 0.336 | train-f1: 96.625 val-f1: 91.000
# epoch: 192 | train loss: 0.198 | val loss: 0.329 | train-f1: 95.188 val-f1: 91.000
# epoch: 193 | train loss: 0.212 | val loss: 0.329 | train-f1: 95.750 val-f1: 91.000
# epoch: 194 | train loss: 0.197 | val loss: 0.331 | train-f1: 95.688 val-f1: 91.000
# epoch: 195 | train loss: 0.217 | val loss: 0.322 | train-f1: 94.125 val-f1: 91.000
# epoch: 196 | train loss: 0.234 | val loss: 0.335 | train-f1: 94.062 val-f1: 91.000
# epoch: 197 | train loss: 0.255 | val loss: 0.327 | train-f1: 94.312 val-f1: 91.000
# epoch: 198 | train loss: 0.208 | val loss: 0.329 | train-f1: 95.375 val-f1: 89.500
# epoch: 199 | train loss: 0.258 | val loss: 0.330 | train-f1: 94.562 val-f1: 91.000
# epoch: 200 | train loss: 0.200 | val loss: 0.321 | train-f1: 95.562 val-f1: 91.000
# Total Time: 44.388

# %%
def plot_res(metric_hist,name):

    fig = make_subplots(rows=1, cols=2,
                        subplot_titles=['lost_hist',f'metric_{name}'])

    # Training Data

    fig.add_trace(go.Scatter(x=[*range(1,epochs+1)],
                             y=loss_hist["train"],
                              line=dict(color="#94D4F6",width=2),
                             name='train-loss'),row=1, col=1)
    fig.add_trace(go.Scatter(x=[*range(1,epochs+1)],
                             y=metric_hist["train"][name],
                             line=dict(color="#94D4F6",width=2),
                             name=f'train-{name}'),row=1, col=2)

    # Validation Data

    fig.add_trace(go.Scatter(x=[*range(1,epochs+1)],
                             y=loss_hist["val"],
                             line=dict(color="#454545",width=2),
                             name='val-loss'),row=1, col=1)
    fig.add_trace(go.Scatter(x=[*range(1,epochs+1)],
                             y=metric_hist["val"][name],
                             line=dict(color="#454545",width=2),
                             name=f'val-{name}'),row=1, col=2)

    fig.update_layout(template='plotly_white',
                      title='Train / Validation Data Splitting',
                      font=dict(family='sans-serif',size=12),
                      width=1200)

    fig.update_traces({'marker_line_width':3,
                       'marker_line_color':"black",
                       'marker_size':8,
                       'opacity':1.0,
                       'marker':{'showscale':True,'reversescale':True, 'cmid':0, 'size':10},
                      })

    fig.update_coloraxes(colorscale="tealgrn")
    fig.update_layout(coloraxis_showscale=False)
    fig.show(renderer='svg')

plot_res(metric_hist,'f1')

# %%
X_test, y_test = val_dataset[:10]

model.eval()
logits = nn_model(X_test.to(device))
probs = torch.sigmoid(logits)
probs

threshold = .5
confusion_matrix(y_test[:10], (probs.cpu() >= threshold))
# Out:
# array([[4, 0],
#        [0, 6]])
